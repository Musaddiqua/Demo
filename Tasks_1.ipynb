# %% [markdown]
# <a href="https://colab.research.google.com/github/Musaddiqua/AIL/blob/main/Tasks_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# print("2+2")
# print(2+2)

# #variables
# num_1 =int(input("enter a number: "))
# num_2 =int(input("enter a number: "))
# # print(num_2)
# print(num_2 * num_1)
# print(num_2 / num_1)
# print(num_2 % num_1)
# print(num_2 // num_1)
# #string
# fname = 'mush'
# lname = 'gwen'
# print(fname + " "+ lname )
#datatypes
num1 =float(input("enter a number: "))
num2 =int(input("enter a number: "))
if num1 > num2:
  print("num1 is greater than num2")
else:
  print("num2 is greater than num1")
# print(num1 > num2)
# print(num1 >= num2)
# print(num1 ==2 num2)

#greatest among three numbers using nested

# a = 1
# b = 4
# c = 5
# if a > b:
#   if a > c:
#     print("a is greater")
#   else:
#     print("c is greater")
# else:
#    if b > c:
#     print("b is greater")

# check if number is odd or even
# Out:
# enter a number: 2
# enter a number: 3
# num2 is greater than num1

# %%
# check if number is odd or even
a = int(input("enter a number: "))
if a % 2 == 0:
  print("a is even")
else:
  print("a is odd")
# Out:
# enter a number: 23
# a is odd

# %%
# number is positive or negative or zero
a = int(input("enter a number: "))
if a > 0:
  print("a is positive")
elif a < 0:
  print("a is negative")
else:
  print("a is zero")
# Out:
# enter a number: 0
# a is zero

# %%
# if number is prime or not
a = int(input("enter a number: "))
if a <=1:
  print("not a prime number")
else:
  for i in range(2,a):
    if a % i == 0:
      print("not a prime number")
      break
  else:
      print("prime number")
# Out:
# enter a number: 5
# prime number

# %%
# word or number is palindrome
a = input("enter a word or number: ")
if a == a[::-1]:
  print("palindrome")

else:
  print("not a palindrome")
# Out:
# enter a word or number: weew
# palindrome

# %%
# checking leap year
a = int(input("Enter a year: "))

if (a % 4 == 0 and a % 100 != 0) or (a % 400 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter a year: 2004
# Leap Year

# %%
# enter username and password and result as login successfull
username = input("Enter your username: ")
password = input("Enter your password: ")
if username == "admin" and password == "admin123":
    print("Login successful")
    print("Welcome, admin!")
else:
    print("Invalid username or password")
# Out:
# Enter your username: admin
# Enter your password: admin123
# Login successful
# Welcome, admin!

# %%
# Rock Paper Scissors
import random

print("Welcome to the Game ")

while True:
    player_1 = input("Enter your choice (rock/paper/scissors): ").lower()
    player_2 = random.choice(["rock", "paper", "scissors"])

    print("Computer chose:", player_2)

    if player_1 == player_2:
        print("Tie ")

    elif player_1 == "rock" and player_2 == "scissors":
        print("Player 1 Wins ")

    elif player_1 == "paper" and player_2 == "rock":
        print("Player 1 Wins ")

    elif player_1 == "scissors" and player_2 == "paper":
        print("Player 1 Wins ")

    else:
        print("Computer Wins ")

    play_again = input("Do you want to play again? (yes/no): ")

    if play_again.lower() != "yes":
        print("Game Over ")
        break
# Out:
# Welcome to the Game
# Enter your choice (rock/paper/scissors): rock
# Computer chose: rock
# Tie
# Do you want to play again? (yes/no): no
# Game Over
